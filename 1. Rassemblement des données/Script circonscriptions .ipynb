# %% [markdown]
# # Importation des données

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
circo_leg2 = pd.read_excel('https://www.data.gouv.fr/fr/datasets/r/41483dcf-4c61-4e30-b7f8-d10396d28040', sheet_name = 'Circo. leg. T2', header = 2)
circo_leg1 = pd.read_excel('https://www.data.gouv.fr/fr/datasets/r/3eb503cd-49cf-4e04-9efd-7262580f7fc7', sheet_name = 'Circo. leg. T1', header = 2)
sociodemographie = pd.read_excel('https://www.insee.fr/fr/statistiques/fichier/2542357/indic-stat-2013-circonscriptions-legislatives.xls', sheet_name = 'indicateurs-circonscriptions', header = 6)

# %% [markdown]
# ## Nettoyage de la base des résultats électoraux

# %% [raw]
# On ne garde que les circonscriptions de France métropolitaine

# %%
circo_leg2['HorsMetropole']=[str(s)[0] for s in circo_leg2['Code du département']]
circo_leg2=circo_leg2[circo_leg2['HorsMetropole']!="Z"]
circo_leg2=circo_leg2.drop(columns=["HorsMetropole"])

circo_leg1['HorsMetropole']=[str(s)[0] for s in circo_leg1['Code du département']]
circo_leg1=circo_leg1[circo_leg1['HorsMetropole']!="Z"]
circo_leg1=circo_leg1.drop(columns=["HorsMetropole"])

# %% [raw]
# On ne garde des données que sur le député élu. Au second tour, c'est assez facile. Pour le premier tour, il faut se servir du député élu au second tour pour supprimer les colonnes inutiles

# %%
circo_leg2=circo_leg2.drop(columns=['N°Panneau.1', 'Sexe.1', 'Nom.1', 'Prénom.1', 'Nuance.1', 'Voix.1',
       '% Voix/Ins.1', '% Voix/Exp.1', 'Sièges.1', 'N°Panneau.2', 'Sexe.2',
       'Nom.2', 'Prénom.2', 'Nuance.2', 'Voix.2', '% Voix/Ins.2',
       '% Voix/Exp.2', 'Sièges.2','N°Panneau',"Libellé de la circonscription",'Sièges','Votants','% Abs/Ins', '% Vot/Ins','% Blancs/Ins', '% Blancs/Vot','% Nuls/Ins', '% Nuls/Vot', 'Exprimés', '% Exp/Ins',
       '% Exp/Vot','Libellé du département','Sexe'])
circo_leg2.columns
# Out:
# Index(['Code du département', 'Code de la circonscription', 'Inscrits',
#        'Abstentions', 'Blancs', 'Nuls', 'Nom', 'Prénom', 'Nuance', 'Voix',
#        '% Voix/Ins', '% Voix/Exp'],
#       dtype='object')

# %%
Nuance=[0 for j in range(len(circo_leg1['Nom']))]
Voix=[0 for j in range(len(circo_leg1['Nom']))]
Voix_Ins=[0 for j in range(len(circo_leg1['Nom']))]
Voix_Exp=[0 for j in range(len(circo_leg1['Nom']))]
#Premiere colonne de noms et prénoms

for i in range (1,26):
    nom="Nom."+str(i)
    prenom="Prénom."+str(i)
    prov=circo_leg2[['Nom','Prénom']].merge(circo_leg1[[nom,prenom]],left_on=['Nom','Prénom'],right_on=[nom,prenom],how='left').dropna().index.to_list()
    nuance="Nuance."+str(i)
    voix="Voix."+str(i)
    voix_ins="% Voix/Ins."+str(i)
    voix_exp="% Voix/Exp."+str(i)
    for j in prov:
        Nuance[j]=circo_leg1[nuance].iloc[j]
        Voix[j]=circo_leg1[voix].iloc[j]
        Voix_Ins=circo_leg1[voix_ins].iloc[j]
        Voix_Ens=circo_leg1[voix_exp].iloc[j]
circo_leg1=circo_leg1[['Code du département','Code de la circonscription','Libellé de la circonscription','Inscrits','Abstentions','Blancs','Nuls']]
circo_leg1['Nuance']=Nuance
circo_leg1['Voix']=Voix
circo_leg1['% Voix/Exp']=Voix_Ens
circo_leg1['% Voix/Ins']=Voix_Ins

# %%
circo=pd.merge(circo_leg2, circo_leg1, on=['Code du département', 'Code de la circonscription'],suffixes=('_T2', '_T1'))
circo.columns
# Out:
# Index(['Code du département', 'Code de la circonscription', 'Inscrits_T2',
#        'Abstentions_T2', 'Blancs_T2', 'Nuls_T2', 'Nom', 'Prénom', 'Nuance_T2',
#        'Voix_T2', '% Voix/Ins_T2', '% Voix/Exp_T2',
#        'Libellé de la circonscription', 'Inscrits_T1', 'Abstentions_T1',
#        'Blancs_T1', 'Nuls_T1', 'Nuance_T1', 'Voix_T1', '% Voix/Exp_T1',
#        '% Voix/Ins_T1'],
#       dtype='object')

# %% [markdown]
# ## Nettoyage de la base socio-démographique

# %% [raw]
# On va maintenant fusionner avec la base sociodemographie

# %%
sociodemographie.head(10)
# Out:
#   DEPCIR              DEPCIR_INTITULE        P13_pop  P13_pop0002  \
# 0   0101   Ain  - 1re circonscription  115682.800721  2874.326056
# 1   0102    Ain  - 2e circonscription  129760.000000  3325.731889
# 2   0103    Ain  - 3e circonscription  131843.000000  3829.305954
# 3   0104    Ain  - 4e circonscription  126379.199279  3092.987282
# 4   0105    Ain  - 5e circonscription  115832.000000  3100.735646
# 5   0201  Aisne - 1re circonscription  105282.000000  2768.598936
# 6   0202   Aisne - 2e circonscription  108259.000000  2694.946212
# 7   0203   Aisne - 3e circonscription   96414.000000  2436.695697
# 8   0204   Aisne - 4e circonscription  113905.000000  2785.226025
# 9   0205   Aisne - 5e circonscription  116207.000000  2983.139570
#
#    P13_pop0305  P13_pop0610   P13_pop1117   P13_pop1824   P13_pop2539  \
# 0  4429.288087  7558.644853  10511.266444   8473.081349  19969.929591
# 1  5273.583332  9193.151067  13045.324265  10288.109487  23322.551783
# 2  5894.832710  9649.715431  12388.727788   8183.936937  28579.122298
# 3  4743.761913  8662.724249  12540.670324   9391.752419  21762.829287
# 4  4759.693324  8177.573026  10607.628411   7989.938189  20958.701607
# 5  4044.389460  7097.638807   9573.511640   7963.438996  19209.507315
# 6  4149.723447  6918.860559   9948.432909   8882.783201  19033.538668
# 7  3827.212184  6355.817448   9128.970215   6968.700800  16144.102046
# 8  4053.494903  7122.192999  10243.472532   9105.022933  19287.854396
# 9  4492.087379  7773.239084  11148.603764   8163.912142  20429.496308
#
#     P13_pop4054  ...  C13_F15P_cs3  C13_F15P_cs4  C13_F15P_cs5  C13_F15P_cs6  \
# 0  24006.114092  ...   2316.360985   7414.467118  12157.292638   2908.892800
# 1  29698.306594  ...   3884.213675   9275.658349  13217.048954   3171.511925
# 2  30028.956253  ...   4580.765185   9330.496576  14137.864372   2495.812921
# 3  27773.926430  ...   2371.894157   8115.627574  14168.067924   3409.006084
# 4  24866.117493  ...   1985.046884   6203.685147  11030.827186   5326.656465
# 5  21610.343824  ...   1622.750952   5421.724477  11660.599624   2580.309796
# 6  21203.037667  ...   1702.752602   5510.073307  11248.870599   2841.128367
# 7  19137.243731  ...    906.266594   3514.401193   9252.503019   2647.077545
# 8  22979.881305  ...   1506.237734   5811.994026  12072.732143   2855.006957
# 9  25475.368512  ...   1914.154030   6140.626888  12998.921130   3835.978852
#
#    C13_F15P_cs7  C13_F15P_cs8        P13_rp       C13_pmen  C13_pmen_menfam  \
# 0  15218.990845   7691.594315  49794.660605  112841.423991     93972.726123
# 1  12564.461202   9691.058260  49832.879587  126194.537962    111947.821492
# 2  11374.737793  11193.509587  55530.909874  129769.193862    108977.420065
# 3  14584.928837   7906.835915  51484.108188  122974.019372    106337.434182
# 4  12945.962271   8937.812821  48552.687766  113193.571711     95537.461629
# 5  12641.363656   9792.697531  44169.305031  102292.390534     85981.425374
# 6  14497.982294  10662.402361  47015.110853  106328.524036     88245.784423
# 7  12786.624702  10454.089337  40225.606038   94914.684269     80621.395730
# 8  14570.224447  11601.494479  49548.157498  111905.884882     93181.357026
# 9  12893.048354   8854.505629  47466.693707  114028.255130     98299.357647
#
#    C13_pmen_menseul
# 0      16784.334716
# 1      12264.117253
# 2      17972.199210
# 3      14689.572852
# 4      15471.847653
# 5      13977.569301
# 6      15801.540314
# 7      12342.644468
# 8      16533.641693
# 9      13435.656658
#
# [10 rows x 57 columns]

# %% [raw]
# Signification des variables
# https://www.insee.fr/fr/statistiques/2542357#dictionnaire
# On ne va garder que les variables intéressantes pour nous

# %%
sociodemographie

# %%
#On créé DEPSIR pour la fusion
circo["Code du département"] = [s if len(str(s)) == 2 else "0" + str(s) for s in circo["Code du département"]]
circo["Code de la circonscription"] = [s if len(str(s)) == 2 else "0" + str(s) for s in circo["Code de la circonscription"]]
circo["DEPSIR"] = circo["Code du département"].astype(str) + circo["Code de la circonscription"].astype(str)
sociodemographie['DEPSIR']=sociodemographie['DEPCIR']
sociodemographie=sociodemographie.drop(columns='DEPCIR')
basefinale = pd.merge(circo, sociodemographie, on = "DEPSIR", how = "left")

# %%
basefinale.head(10)
# Out:
#   Code du département Code de la circonscription  Inscrits_T2  Abstentions_T2  \
# 0                  01                         01        82673           46945
# 1                  01                         02        93507           54341
# 2                  01                         03        75548           46438
# 3                  01                         04        89382           51079
# 4                  01                         05        75289           43569
# 5                  02                         01        72347           39583
# 6                  02                         02        73976           42321
# 7                  02                         03        68085           36747
# 8                  02                         04        79114           47083
# 9                  02                         05        82224           45241
#
#    Blancs_T2  Nuls_T2                Nom      Prénom Nuance_T2  Voix_T2  ...  \
# 0       2245      805             BRETON      Xavier        LR    17564  ...
# 1       2424      867  DE LA VERPILLIÈRE     Charles        LR    18556  ...
# 2       1815      539           GIVERNET        Olga       REM    16552  ...
# 3       2670      697          TROMPILLE    Stéphane       REM    22532  ...
# 4       2050      749               ABAD      Damien        LR    19383  ...
# 5       2262      824      BONO-VANDORME        Aude       REM    16684  ...
# 6       1672      709               DIVE      Julien        LR    19019  ...
# 7       1606      687            BRICOUT  Jean-Louis       SOC    17558  ...
# 8       2192      952            DELATTE        Marc       REM    16256  ...
# 9       2253      817             KRABAL     Jacques       REM    19609  ...
#
#    C13_F15P_cs3  C13_F15P_cs4  C13_F15P_cs5  C13_F15P_cs6  C13_F15P_cs7  \
# 0   2316.360985   7414.467118  12157.292638   2908.892800  15218.990845
# 1   3884.213675   9275.658349  13217.048954   3171.511925  12564.461202
# 2   4580.765185   9330.496576  14137.864372   2495.812921  11374.737793
# 3   2371.894157   8115.627574  14168.067924   3409.006084  14584.928837
# 4   1985.046884   6203.685147  11030.827186   5326.656465  12945.962271
# 5   1622.750952   5421.724477  11660.599624   2580.309796  12641.363656
# 6   1702.752602   5510.073307  11248.870599   2841.128367  14497.982294
# 7    906.266594   3514.401193   9252.503019   2647.077545  12786.624702
# 8   1506.237734   5811.994026  12072.732143   2855.006957  14570.224447
# 9   1914.154030   6140.626888  12998.921130   3835.978852  12893.048354
#
#    C13_F15P_cs8        P13_rp       C13_pmen  C13_pmen_menfam  \
# 0   7691.594315  49794.660605  112841.423991     93972.726123
# 1   9691.058260  49832.879587  126194.537962    111947.821492
# 2  11193.509587  55530.909874  129769.193862    108977.420065
# 3   7906.835915  51484.108188  122974.019372    106337.434182
# 4   8937.812821  48552.687766  113193.571711     95537.461629
# 5   9792.697531  44169.305031  102292.390534     85981.425374
# 6  10662.402361  47015.110853  106328.524036     88245.784423
# 7  10454.089337  40225.606038   94914.684269     80621.395730
# 8  11601.494479  49548.157498  111905.884882     93181.357026
# 9   8854.505629  47466.693707  114028.255130     98299.357647
#
#    C13_pmen_menseul
# 0      16784.334716
# 1      12264.117253
# 2      17972.199210
# 3      14689.572852
# 4      15471.847653
# 5      13977.569301
# 6      15801.540314
# 7      12342.644468
# 8      16533.641693
# 9      13435.656658
#
# [10 rows x 78 columns]

# %% [markdown]
# ## Transformation en pourcentages

# %%
for name in ["C13_Pop15P_cs1", "C13_Pop15P_cs2", "C13_Pop15P_cs3", "C13_Pop15P_cs4", "C13_Pop15P_cs5", "C13_Pop15P_cs6", "C13_Pop15P_cs7", "C13_Pop15P_cs8"]:
    basefinale[name] = (basefinale[name].astype(int))/(basefinale["P13_Pop15P"].astype(int))*100
for name in ["C13_H15P_cs1", "C13_H15P_cs2", "C13_H15P_cs3", "C13_H15P_cs4","C13_H15P_cs5", "C13_H15P_cs6", "C13_H15P_cs7", "C13_H15P_cs8"]:
    basefinale[name] = basefinale[name].astype(int)/basefinale["C13_H15P"].astype(int)*100 
for name in ["C13_F15P_cs1", "C13_F15P_cs2", "C13_F15P_cs3", "C13_F15P_cs4", "C13_F15P_cs5","C13_F15P_cs6", "C13_F15P_cs7", "C13_F15P_cs8"]: 
    basefinale[name] = basefinale[name].astype(int)/basefinale["C13_F15P"].astype(int)*100 
for name in ["P13_pop0002", "P13_pop0305", "P13_pop0610", "P13_pop1117", "P13_pop1824", "P13_pop2539", "P13_pop4054", "P13_pop5564", "P13_pop6579", "P13_pop80p", "P13_pop0019", "P13_pop2064", "P13_pop65P"] : 
    basefinale[name] = basefinale[name].astype(int)/basefinale["P13_pop"].astype(int)*100  
for name in ["P13_h0019", "P13_h2064", "P13_h65p"] :
    basefinale[name] = basefinale[name].astype(int)/basefinale["P13_poph"].astype(int)*100 
for name in ["P13_f0019", "P13_f2064", "P13_f65p"] :
    basefinale[name] = basefinale[name].astype(int)/basefinale["P13_popf"].astype(int)*100 
for name in ["P13_pop_fr","P13_pop_etr"] : 
    basefinale[name] = basefinale[name].astype(int)/basefinale["P13_pop"].astype(int)*100

# %%
basefinale.head(10)
# Out:
#   Code du département Code de la circonscription  Inscrits_T2  Abstentions_T2  \
# 0                  01                         01        82673           46945
# 1                  01                         02        93507           54341
# 2                  01                         03        75548           46438
# 3                  01                         04        89382           51079
# 4                  01                         05        75289           43569
# 5                  02                         01        72347           39583
# 6                  02                         02        73976           42321
# 7                  02                         03        68085           36747
# 8                  02                         04        79114           47083
# 9                  02                         05        82224           45241
#
#    Blancs_T2  Nuls_T2                Nom      Prénom Nuance_T2  Voix_T2  ...  \
# 0       2245      805             BRETON      Xavier        LR    17564  ...
# 1       2424      867  DE LA VERPILLIÈRE     Charles        LR    18556  ...
# 2       1815      539           GIVERNET        Olga       REM    16552  ...
# 3       2670      697          TROMPILLE    Stéphane       REM    22532  ...
# 4       2050      749               ABAD      Damien        LR    19383  ...
# 5       2262      824      BONO-VANDORME        Aude       REM    16684  ...
# 6       1672      709               DIVE      Julien        LR    19019  ...
# 7       1606      687            BRICOUT  Jean-Louis       SOC    17558  ...
# 8       2192      952            DELATTE        Marc       REM    16256  ...
# 9       2253      817             KRABAL     Jacques       REM    19609  ...
#
#    C13_F15P_cs3  C13_F15P_cs4 C13_F15P_cs5  C13_F15P_cs6  C13_F15P_cs7  \
# 0      4.748237     15.200098    24.924143      5.961948     31.199770
# 1      7.327196     17.497359    24.933972      5.982116     23.702083
# 2      8.445354     17.204182    26.068116      4.600690     20.973244
# 3      4.567169     15.631622    27.291289      6.566629     28.092615
# 4      4.187234     13.084842    23.267097     11.234865     27.306670
# 5      3.638321     12.159889    26.154640      5.787219     28.355129
# 6      3.605627     11.672740    23.828489      6.018558     30.711380
# 7      2.223367      8.623525    22.704852      6.495865     31.377457
# 8      3.057061     11.795871    24.505207      5.795425     29.575949
# 9      3.995658     12.817836    27.134566      8.005929     26.915369
#
#    C13_F15P_cs8        P13_rp       C13_pmen  C13_pmen_menfam  \
# 0     15.768001  49794.660605  112841.423991     93972.726123
# 1     18.282146  49832.879587  126194.537962    111947.821492
# 2     20.639487  55530.909874  129769.193862    108977.420065
# 3     15.229033  51484.108188  122974.019372    106337.434182
# 4     18.852044  48552.687766  113193.571711     95537.461629
# 5     21.964514  44169.305031  102292.390534     85981.425374
# 6     22.587069  47015.110853  106328.524036     88245.784423
# 7     25.654617  40225.606038   94914.684269     80621.395730
# 8     23.549114  49548.157498  111905.884882     93181.357026
# 9     18.483571  47466.693707  114028.255130     98299.357647
#
#    C13_pmen_menseul
# 0      16784.334716
# 1      12264.117253
# 2      17972.199210
# 3      14689.572852
# 4      15471.847653
# 5      13977.569301
# 6      15801.540314
# 7      12342.644468
# 8      16533.641693
# 9      13435.656658
#
# [10 rows x 78 columns]

# %%
basefinale.to_csv("basefinale.csv", ";")
